# %%
 Inputs: 
    Name, Generation, Type
Outputs:
    Name, Generation, Type, Strength, Region, Food they eat, abilities
Algorith: 
    Import pandas
    Get data
    Input Name, Generation, Type
    Sort the database
    Filter out data using the input of the user
    Print out the pokemons attributes

# %%
import pandas as pd

# %%
mydata = pd.read_csv('pokemon.csv')
mydata.sample(10)
# Out:
#                                              abilities  against_bug  \
# 155                            ['Blaze', 'Flash Fire']          0.5
# 596                                     ['Iron Barbs']          1.0
# 36   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...          0.5
# 563             ['Solid Rock', 'Sturdy', 'Swift Swim']          1.0
# 314     ['Natural Cure', 'Poison Point', 'Leaf Guard']          1.0
# 583         ['Ice Body', 'Snow Warning', 'Weak Armor']          1.0
# 572         ['Cute Charm', 'Technician', 'Skill Link']          1.0
# 323          ['White Smoke', 'Drought', 'Shell Armor']          0.5
# 239                     ['Flame Body', 'Vital Spirit']          0.5
# 78           ['Oblivious', 'Own Tempo', 'Regenerator']          2.0
#
#      against_dark  against_dragon  against_electric  against_fairy  \
# 155           1.0             1.0               1.0            0.5
# 596           1.0             0.5               0.5            0.5
# 36            1.0             1.0               1.0            0.5
# 563           1.0             1.0               2.0            1.0
# 314           1.0             1.0               0.5            0.5
# 583           1.0             1.0               1.0            1.0
# 572           1.0             1.0               1.0            1.0
# 323           1.0             1.0               1.0            0.5
# 239           1.0             1.0               1.0            0.5
# 78            2.0             1.0               2.0            1.0
#
#      against_fight  against_fire  against_flying  against_ghost  ...  \
# 155            1.0          0.50             1.0            1.0  ...
# 596            2.0          4.00             1.0            1.0  ...
# 36             1.0          0.50             1.0            1.0  ...
# 563            2.0          0.25             0.5            1.0  ...
# 314            0.5          2.00             2.0            1.0  ...
# 583            2.0          2.00             1.0            1.0  ...
# 572            2.0          1.00             1.0            0.0  ...
# 323            1.0          0.50             1.0            1.0  ...
# 239            1.0          0.50             1.0            1.0  ...
# 78             0.5          0.50             1.0            2.0  ...
#
#      percentage_male  pokedex_number  sp_attack  sp_defense  speed   type1  \
# 155             88.1             156         80          65     80    fire
# 596             50.0             597         24          86     10   grass
# 36              24.6              37         50          65     65    fire
# 563             88.1             564         53          45     22   water
# 314             50.0             315        100          80     65   grass
# 583             50.0             584        110          95     79     ice
# 572             24.6             573         65          60    115  normal
# 323             50.0             324         85          70     20    fire
# 239             75.4             240         70          55     83    fire
# 78              50.0              79         40          40     15   water
#
#        type2  weight_kg  generation  is_legendary
# 155      NaN       19.0           2             0
# 596    steel       18.8           5             0
# 36       ice        NaN           1             0
# 563     rock       16.5           5             0
# 314   poison        2.0           3             0
# 583      NaN       57.5           5             0
# 572      NaN        7.5           5             0
# 323      NaN       80.4           3             0
# 239      NaN       21.4           2             0
# 78   psychic       36.0           1             0
#
# [10 rows x 41 columns]

# %%
mydata['name'].sample(10)
# Out:
# 480       Mesprit
# 389      Chimchar
# 358         Absol
# 677      Meowstic
# 173     Igglybuff
# 90       Cloyster
# 536    Seismitoad
# 581     Vanillite
# 182        Marill
# 239         Magby
# Name: name, dtype: object

# %%
mydata['type1'].sample(10)
# Out:
# 420      grass
# 22      poison
# 748     ground
# 455      water
# 249       fire
# 7        water
# 163     normal
# 4         fire
# 64     psychic
# 507     normal
# Name: type1, dtype: object

# %%
mydata['type1'].value_counts()
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: type1, dtype: int64

# %%
mydata['generation'].value_counts()
# Out:
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     80
# 6     72
# Name: generation, dtype: int64

# %%
names = pd.Series( data = ['Bulbasaur','Ivysaur','Venusaur','Charmander','Charmeleon'])
generation = pd.Series( data = [1, 2, 3, 4, 5, 6, 7])
types = pd.Series( data = ['ground', 'water', 'electric', 'fire', 'normal', 'bug', 'rock', 'dragon', 'fighting', 'ice', 'poison', 'ghost', 'steel', 'flying', 'dark', 'fairy'])
series_dict = { 'Name':  names, 'Generation': generation, 'Types' : types }
pokemons = pd.DataFrame( series_dict )
pokemons
# Out:
#           Name  Generation     Types
# 0    Bulbasaur         1.0    ground
# 1      Ivysaur         2.0     water
# 2     Venusaur         3.0  electric
# 3   Charmander         4.0      fire
# 4   Charmeleon         5.0    normal
# 5          NaN         6.0       bug
# 6          NaN         7.0      rock
# 7          NaN         NaN    dragon
# 8          NaN         NaN  fighting
# 9          NaN         NaN       ice
# 10         NaN         NaN    poison
# 11         NaN         NaN     ghost
# 12         NaN         NaN     steel
# 13         NaN         NaN    flying
# 14         NaN         NaN      dark
# 15         NaN         NaN     fairy

# %%
pokemons = mydata['name']
generation = mydata['generation']
#types = mydata['type1']
print(pokemons)
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28       Nidoran♀
# 29       Nidorina
#           ...
# 771    Type: Null
# 772      Silvally
# 773        Minior
# 774        Komala
# 775    Turtonator
# 776    Togedemaru
# 777       Mimikyu
# 778       Bruxish
# 779        Drampa
# 780      Dhelmise
# 781      Jangmo-o
# 782      Hakamo-o
# 783       Kommo-o
# 784     Tapu Koko
# 785     Tapu Lele
# 786     Tapu Bulu
# 787     Tapu Fini
# 788        Cosmog
# 789       Cosmoem
# 790      Solgaleo
# 791        Lunala
# 792      Nihilego
# 793      Buzzwole
# 794     Pheromosa
# 795     Xurkitree
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, Length: 801, dtype: object

# %%
pv = input("Enter: ").title()
print(pv)
# Out:
# Enter: ate my food
# Ate My Food

# %%
pok = input("Enter the pokemon's name, generation or type: ").title()
if pok == pokemons: 
    print(pok) 
#elif pok == generation: 
    #print(pok)
#elif pok == types: 
   # print(pok)
else:
    print("Not able to determone the pokemon")
# Out:
# Enter the pokemon's name, generation or type: guzzlord
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-1a86d9ad6f8d> in <module>
#       1 pok = input("Enter the pokemon's name, generation or type: ").title()
# ----> 2 if pok == pokemons:
#       3     print(pok)
#       4 #elif pok == generation:
#       5     #print(pok)
#
# c:\users\jesus\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477         raise ValueError("The truth value of a {0} is ambiguous. "
#    1478                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1479                          .format(self.__class__.__name__))
#    1480
#    1481     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
print("Highest grade:", mydata.max())
print("Average grade:", mydata.mean())
print("lowest grade:", mydata.min())
print("Sum of grades:", mydata.sum())
print("Count of grades", mydata.count())
# Out:
# Highest grade: abilities            ['Wonder Skin ', 'Magic Guard', 'Tinted Lens']
# against_bug                                                       4
# against_dark                                                      4
# against_dragon                                                    2
# against_electric                                                  4
# against_fairy                                                     4
# against_fight                                                     4
# against_fire                                                      4
# against_flying                                                    4
# against_ghost                                                     4
# against_grass                                                     4
# against_ground                                                    4
# against_ice                                                       4
# against_normal                                                    1
# against_poison                                                    4
# against_psychic                                                   4
# against_rock                                                      4
# against_steel                                                     4
# against_water                                                     4
# attack                                                          185
# base_egg_steps                                                30720
# base_happiness                                                  140
# base_total                                                      780
# capture_rate                                                     90
# classfication                                     Zen Charm Pokémon
# defense                                                         230
# experience_growth                                           1640000
# height_m                                                       14.5
# hp                                                              255
# japanese_name                               Zygarde (10% Forme)ジガルデ
# name                                                        Zygarde
# percentage_male                                                 100
# pokedex_number                                                  801
# sp_attack                                                       194
# sp_defense                                                      230
# speed                                                           180
# type1                                                         water
# weight_kg                                                     999.9
# generation                                                        7
# is_legendary                                                      1
# dtype: object
# Average grade: against_bug          9.962547e-01
# against_dark         1.057116e+00
# against_dragon       9.687890e-01
# against_electric     1.073970e+00
# against_fairy        1.068976e+00
# against_fight        1.065543e+00
# against_fire         1.135456e+00
# against_flying       1.192884e+00
# against_ghost        9.850187e-01
# against_grass        1.034020e+00
# against_ground       1.098002e+00
# against_ice          1.208177e+00
# against_normal       8.870162e-01
# against_poison       9.753433e-01
# against_psychic      1.005306e+00
# against_rock         1.250312e+00
# against_steel        9.834582e-01
# against_water        1.058365e+00
# attack               7.785768e+01
# base_egg_steps       7.191011e+03
# base_happiness       6.536205e+01
# base_total           4.283770e+02
# defense              7.300874e+01
# experience_growth    1.054996e+06
# height_m             1.163892e+00
# hp                   6.895880e+01
# percentage_male      5.515576e+01
# pokedex_number       4.010000e+02
# sp_attack            7.130587e+01
# sp_defense           7.091136e+01
# speed                6.633458e+01
# weight_kg            6.137810e+01
# generation           3.690387e+00
# is_legendary         8.739076e-02
# dtype: float64
# lowest grade: abilities            ['Adaptability', 'Download', 'Analytic']
# against_bug                                              0.25
# against_dark                                             0.25
# against_dragon                                              0
# against_electric                                            0
# against_fairy                                            0.25
# against_fight                                               0
# against_fire                                             0.25
# against_flying                                           0.25
# against_ghost                                               0
# against_grass                                            0.25
# against_ground                                              0
# against_ice                                              0.25
# against_normal                                              0
# against_poison                                              0
# against_psychic                                             0
# against_rock                                             0.25
# against_steel                                            0.25
# against_water                                            0.25
# attack                                                      5
# base_egg_steps                                           1280
# base_happiness                                              0
# base_total                                                180
# capture_rate                                              100
# classfication                               Abundance Pokémon
# defense                                                     5
# experience_growth                                      600000
# height_m                                                  0.1
# hp                                                          1
# japanese_name                                   Abagouraアバゴーラ
# name                                                Abomasnow
# percentage_male                                             0
# pokedex_number                                              1
# sp_attack                                                  10
# sp_defense                                                 20
# speed                                                       5
# type1                                                     bug
# weight_kg                                                 0.1
# generation                                                  1
# is_legendary                                                0
# dtype: object
# Sum of grades: abilities            ['Overgrow', 'Chlorophyll']['Overgrow', 'Chlor...
# against_bug                                                        798
# against_dark                                                    846.75
# against_dragon                                                     776
# against_electric                                                860.25
# against_fairy                                                   856.25
# against_fight                                                    853.5
# against_fire                                                     909.5
# against_flying                                                   955.5
# against_ghost                                                      789
# against_grass                                                   828.25
# against_ground                                                   879.5
# against_ice                                                     967.75
# against_normal                                                   710.5
# against_poison                                                  781.25
# against_psychic                                                 805.25
# against_rock                                                    1001.5
# against_steel                                                   787.75
# against_water                                                   847.75
# attack                                                           62364
# base_egg_steps                                                 5760000
# base_happiness                                                   52355
# base_total                                                      343130
# capture_rate         4545454545454545452551204525512045255120452551...
# classfication        Seed PokémonSeed PokémonSeed PokémonLizard Pok...
# defense                                                          58480
# experience_growth                                            845051720
# height_m                                                           909
# hp                                                               55236
# japanese_name        FushigidaneフシギダネFushigisouフシギソウFushigibanaフシギバ...
# name                 BulbasaurIvysaurVenusaurCharmanderCharmeleonCh...
# percentage_male                                                38774.5
# pokedex_number                                                  321201
# sp_attack                                                        57116
# sp_defense                                                       56800
# speed                                                            53134
# type1                grassgrassgrassfirefirefirewaterwaterwaterbugb...
# weight_kg                                                      47936.3
# generation                                                        2956
# is_legendary                                                        70
# dtype: object
# Count of grades abilities            801
# against_bug          801
# against_dark         801
# against_dragon       801
# against_electric     801
# against_fairy        801
# against_fight        801
# against_fire         801
# against_flying       801
# against_ghost        801
# against_grass        801
# against_ground       801
# against_ice          801
# against_normal       801
# against_poison       801
# against_psychic      801
# against_rock         801
# against_steel        801
# against_water        801
# attack               801
# base_egg_steps       801
# base_happiness       801
# base_total           801
# capture_rate         801
# classfication        801
# defense              801
# experience_growth    801
# height_m             781
# hp                   801
# japanese_name        801
# name                 801
# percentage_male      703
# pokedex_number       801
# sp_attack            801
# sp_defense           801
# speed                801
# type1                801
# type2                417
# weight_kg            781
# generation           801
# is_legendary         801
# dtype: int64

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(str.translate)
# Out:
# Help on method_descriptor:
#
# translate(...)
#     S.translate(table) -> str
#
#     Return a copy of the string S in which each character has been mapped
#     through the given translation table. The table must implement
#     lookup/indexing via __getitem__, for instance a dictionary or list,
#     mapping Unicode ordinals to Unicode ordinals, strings, or None. If
#     this operation raises LookupError, the character is left untouched.
#     Characters mapped to None are deleted.
