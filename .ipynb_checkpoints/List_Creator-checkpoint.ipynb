# %%
list_a = []
while True:
    inp = input('input: ')
    if inp == 'quit':
        print(list_a)
        break
    else:
        list_a.append(inp)
# Out:
# input: shieldon
# input: bastiodon
# input: burmy
# input: wormadam
# input: mothim
# input: combee
# input: vespiquen
# input: pachirisu
# input: buizel
# input: floatzel
# input: cherubi
# input: cherrim
# input: shellos
# input: gastrodon
# input: ambipom
# input: drifloon
# input: drifblim
# input: buneary
# input: lopunny
# input: mismagius
# input: honchkrow
# input: glameow
# input: purugly
# input: chingling
# input: stunky
# input: stuntank
# input: bronzor
# input: bronzong
# input: bonsly
# input: happiny
# input: chatot
# input: spiritomb
# input: gible
# input: gabite
# input: garchomp
# input: munchlax
# input: riolu
# input: lucario
# input: hippopotas
# input: hippowdon
# input: skorupi
# input: drapion
# input: croagunk
# input: toxicroak
# input: carnivine
# input: finneon
# input: lumineon
# input: mantyke
# input: snover
# input: abomasnow
# input: weavile
# input: magnezone
# input: lickilicky
# input: rhyperior
# input: tangrowth
# input: electivire
# ...
