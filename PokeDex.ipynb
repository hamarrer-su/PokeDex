# %%
import pandas as pd

# %%
mydata = pd.read_csv('pokemon.csv')
mydata.sample(10)
# Out:
#                                          abilities  against_bug  against_dark  \
# 705           ['Sap Sipper', 'Hydration', 'Gooey']         1.00           1.0
# 66               ['Guts', 'No Guard', 'Steadfast']         0.50           0.5
# 64   ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00           2.0
# 422   ['Sticky Hold', 'Storm Drain', 'Sand Force']         1.00           1.0
# 377                     ['Clear Body', 'Ice Body']         1.00           1.0
# 201                    ['Shadow Tag', 'Telepathy']         2.00           2.0
# 311                       ['Minus', 'Volt Absorb']         1.00           1.0
# 783      ['Bulletproof', 'Soundproof', 'Overcoat']         0.50           0.5
# 41                  ['Inner Focus', 'Infiltrator']         0.25           1.0
# 362         ['Thick Fat', 'Ice Body', 'Oblivious']         1.00           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# ...
