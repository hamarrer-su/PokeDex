# %%
 Inputs: 
    Name, Generation, Type
Outputs:
    Name, Generation, Type, Strength, Region, abilities
Algorith: 
    Import pandas
    Get data
    Input Name, Generation, Type
    Sort the database
    Filter out data using the input of the user
    Print out the pokemons attributes

# %%
import pandas as pd

# %%
mydata = pd.read_csv('pokemon.csv')
mydata.sample(3)
# Out:
#                                     abilities  against_bug  against_dark  \
# 592   ['Water Absorb', 'Cursed Body', 'Damp']          0.5           2.0
# 543  ['Poison Point', 'Swarm', 'Speed Boost']          0.5           1.0
# 146             ['Shed Skin', 'Marvel Scale']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 592             1.0               2.0            1.0           0.00
# 543             1.0               1.0            0.5           0.25
# 146             2.0               0.5            2.0           1.00
#
#      against_fire  against_flying  against_ghost  ...  percentage_male  \
# 592           0.5             1.0            2.0  ...             50.0
# 543           2.0             2.0            1.0  ...             50.0
# 146           0.5             1.0            1.0  ...             50.0
#
#      pokedex_number  sp_attack  sp_defense  speed   type1   type2  weight_kg  \
# 592             593         85         105     60   water   ghost      135.0
# 543             544         40          79     47     bug  poison       58.5
# 146             147         50          50     50  dragon     NaN        3.3
#
#      generation  is_legendary
# 592           5             0
# 543           5             0
# 146           1             0
#
# [3 rows x 41 columns]

# %%
pokedex_number = pd.Series(mydata['pokedex_number'])
names = pd.Series(mydata['name'])
generation = pd.Series(mydata['generation'])
types = pd.Series(mydata['type1'])
classfication = pd.Series(mydata['classfication'])
abilities = pd.Series(mydata['abilities'])
height = pd.Series(mydata['height_m'])
weight = pd.Series(mydata['weight_kg'])
hp = pd.Series(mydata['hp'])
speed = pd.Series(mydata['speed'])
attack= pd.Series(mydata['attack'])
defense = pd.Series(mydata['defense'])
series_dict = { 'Pokedex Number' : pokedex_number, 'Name':  names, 'Generation': generation, 'Types' : types, 'Classfication' : classfication, 'Abilities' : abilities, 'Height_m' : height, 'Weight_kg' : weight, 'Hp' : hp, 'Speed' : speed, 'sp_Attack' : attack, 'sp_Defense' : defense }
pokemons = pd.DataFrame( series_dict )
pokemons.sample(3)
# Out:
#      Pokedex Number      Name  Generation     Types      Classfication  \
# 648             649  Genesect           5       bug  Paleozoic Pokémon
# 180             181  Ampharos           2  electric      Light Pokémon
# 628             629   Vullaby           5      dark   Diapered Pokémon
#
#                                    Abilities  Height_m  Weight_kg  Hp  Speed  \
# 648                             ['Download']       1.5       82.5  71     99
# 180                       ['Static', 'Plus']       1.4       61.5  90     45
# 628  ['Big Pecks', 'Overcoat', 'Weak Armor']       0.5        9.0  70     60
#
#      sp_Attack  sp_Defense
# 648        120          95
# 180         95         105
# 628         55          75

# %%
pokemons.head(2)
# Out:
#    Pokedex Number       Name  Generation  Types Classfication  \
# 0               1  Bulbasaur           1  grass  Seed Pokémon
# 1               2    Ivysaur           1  grass  Seed Pokémon
#
#                      Abilities  Height_m  Weight_kg  Hp  Speed  sp_Attack  \
# 0  ['Overgrow', 'Chlorophyll']       0.7        6.9  45     45         49
# 1  ['Overgrow', 'Chlorophyll']       1.0       13.0  60     60         62
#
#    sp_Defense
# 0          49
# 1          63

# %%
pokemons[pokemons['Types'] == 'grass' ].head(2)
# Out:
#    Pokedex Number       Name  Generation  Types Classfication  \
# 0               1  Bulbasaur           1  grass  Seed Pokémon
# 1               2    Ivysaur           1  grass  Seed Pokémon
#
#                      Abilities  Height_m  Weight_kg  Hp  Speed  sp_Attack  \
# 0  ['Overgrow', 'Chlorophyll']       0.7        6.9  45     45         49
# 1  ['Overgrow', 'Chlorophyll']       1.0       13.0  60     60         62
#
#    sp_Defense
# 0          49
# 1          63

# %%
pokemons[pokemons['Types'] == 'fire' ].tail(2)
# Out:
#      Pokedex Number        Name  Generation Types         Classfication  \
# 740             741    Oricorio           7  fire       Dancing Pokémon
# 775             776  Turtonator           7  fire  Blast Turtle Pokémon
#
#            Abilities  Height_m  Weight_kg  Hp  Speed  sp_Attack  sp_Defense
# 740       ['Dancer']       0.6        3.4  75     93         70          70
# 775  ['Shell Armor']       2.0      212.0  60     36         78         135

# %%
pokemons[pokemons['Generation'] == 3 ].tail(2)
# Out:
#      Pokedex Number     Name  Generation    Types Classfication  \
# 384             385  Jirachi           3    steel  Wish Pokémon
# 385             386   Deoxys           3  psychic   DNA Pokémon
#
#             Abilities  Height_m  Weight_kg   Hp  Speed  sp_Attack  sp_Defense
# 384  ['Serene Grace']       0.3        1.1  100    100        100         100
# 385      ['Pressure']       1.7       60.8   50    180         95          90

# %%
pokemons[(pokemons.Generation == 3) ]
# Out:
#      Pokedex Number       Name  Generation    Types        Classfication  \
# 251             252    Treecko           3    grass   Wood Gecko Pokémon
# 252             253    Grovyle           3    grass   Wood Gecko Pokémon
# 253             254   Sceptile           3    grass       Forest Pokémon
# 254             255    Torchic           3     fire        Chick Pokémon
# 255             256  Combusken           3     fire   Young Fowl Pokémon
# 256             257   Blaziken           3     fire        Blaze Pokémon
# 257             258     Mudkip           3    water     Mud Fish Pokémon
# 258             259  Marshtomp           3    water     Mud Fish Pokémon
# 259             260   Swampert           3    water     Mud Fish Pokémon
# 260             261  Poochyena           3     dark         Bite Pokémon
# 261             262  Mightyena           3     dark         Bite Pokémon
# 262             263  Zigzagoon           3   normal  Tiny Racoon Pokémon
# 263             264    Linoone           3   normal         Rush Pokémon
# 264             265    Wurmple           3      bug         Worm Pokémon
# 265             266    Silcoon           3      bug       Cocoon Pokémon
# 266             267  Beautifly           3      bug    Butterfly Pokémon
# 267             268    Cascoon           3      bug       Cocoon Pokémon
# 268             269     Dustox           3      bug  Poison Moth Pokémon
# 269             270      Lotad           3    water   Water Weed Pokémon
# 270             271     Lombre           3    water        Jolly Pokémon
# 271             272   Ludicolo           3    water     Carefree Pokémon
# 272             273     Seedot           3    grass        Acorn Pokémon
# 273             274    Nuzleaf           3    grass         Wily Pokémon
# 274             275    Shiftry           3    grass       Wickid Pokémon
# 275             276    Taillow           3   normal  TinySwallow Pokémon
# 276             277    Swellow           3   normal      Swallow Pokémon
# 277             278    Wingull           3    water      Seagull Pokémon
# 278             279   Pelipper           3    water   Water Bird Pokémon
# 279             280      Ralts           3  psychic      Feeling Pokémon
# 280             281     Kirlia           3  psychic      Emotion Pokémon
# ..              ...        ...         ...      ...                  ...
# 356             357    Tropius           3    grass        Fruit Pokémon
# 357             358   Chimecho           3  psychic   Wind Chime Pokémon
# 358             359      Absol           3     dark     Disaster Pokémon
# 359             360     Wynaut           3  psychic       Bright Pokémon
# 360             361    Snorunt           3      ice     Snow Hat Pokémon
# 361             362     Glalie           3      ice         Face Pokémon
# 362             363     Spheal           3      ice         Clap Pokémon
# 363             364     Sealeo           3      ice    Ball Roll Pokémon
# 364             365    Walrein           3      ice    Ice Break Pokémon
# 365             366   Clamperl           3    water      Bivalve Pokémon
# 366             367    Huntail           3    water     Deep Sea Pokémon
# 367             368   Gorebyss           3    water    South Sea Pokémon
# 368             369  Relicanth           3    water    Longevity Pokémon
# 369             370    Luvdisc           3    water   Rendezvous Pokémon
# 370             371      Bagon           3   dragon    Rock Head Pokémon
# 371             372    Shelgon           3   dragon    Endurance Pokémon
# 372             373  Salamence           3   dragon       Dragon Pokémon
# 373             374     Beldum           3    steel    Iron Ball Pokémon
# 374             375     Metang           3    steel    Iron Claw Pokémon
# 375             376  Metagross           3    steel     Iron Leg Pokémon
# 376             377   Regirock           3     rock    Rock Peak Pokémon
# 377             378     Regice           3      ice      Iceberg Pokémon
# 378             379  Registeel           3    steel         Iron Pokémon
# 379             380     Latias           3   dragon          Eon Pokémon
# 380             381     Latios           3   dragon          Eon Pokémon
# 381             382     Kyogre           3    water    Sea Basin Pokémon
# 382             383    Groudon           3   ground    Continent Pokémon
# 383             384   Rayquaza           3   dragon     Sky High Pokémon
# 384             385    Jirachi           3    steel         Wish Pokémon
# 385             386     Deoxys           3  psychic          DNA Pokémon
#
#                                        Abilities  Height_m  Weight_kg   Hp  \
# 251                     ['Overgrow', 'Unburden']       0.5        5.0   40
# 252                     ['Overgrow', 'Unburden']       0.9       21.6   50
# 253                     ['Overgrow', 'Unburden']       1.7       52.2   70
# 254                     ['Blaze', 'Speed Boost']       0.4        2.5   45
# 255                     ['Blaze', 'Speed Boost']       0.9       19.5   60
# 256                     ['Blaze', 'Speed Boost']       1.9       52.0   80
# 257                          ['Torrent', 'Damp']       0.4        7.6   50
# 258                          ['Torrent', 'Damp']       0.7       28.0   70
# 259                          ['Torrent', 'Damp']       1.5       81.9  100
# 260        ['Run Away', 'Quick Feet', 'Rattled']       0.5       13.6   35
# 261        ['Intimidate', 'Quick Feet', 'Moxie']       1.0       37.0   70
# 262         ['Pickup', 'Gluttony', 'Quick Feet']       0.4       17.5   38
# 263         ['Pickup', 'Gluttony', 'Quick Feet']       0.5       32.5   78
# 264                  ['Shield Dust', 'Run Away']       0.3        3.6   45
# 265                                ['Shed Skin']       0.6       10.0   50
# 266                         ['Swarm', 'Rivalry']       1.0       28.4   60
# 267                                ['Shed Skin']       0.7       11.5   50
# 268              ['Shield Dust', 'Compoundeyes']       1.2       31.6   60
# 269     ['Swift Swim', 'Rain Dish', 'Own Tempo']       0.5        2.6   40
# 270     ['Swift Swim', 'Rain Dish', 'Own Tempo']       1.2       32.5   60
# 271     ['Swift Swim', 'Rain Dish', 'Own Tempo']       1.5       55.0   80
# 272  ['Chlorophyll', 'Early Bird', 'Pickpocket']       0.5        4.0   40
# 273  ['Chlorophyll', 'Early Bird', 'Pickpocket']       1.0       28.0   70
# 274  ['Chlorophyll', 'Early Bird', 'Pickpocket']       1.3       59.6   90
# 275                          ['Guts', 'Scrappy']       0.3        2.3   40
# 276                          ['Guts', 'Scrappy']       0.7       19.8   60
# 277       ['Keen Eye', 'Hydration', 'Rain Dish']       0.6        9.5   40
# 278         ['Keen Eye', 'Drizzle', 'Rain Dish']       1.2       28.0   60
# 279        ['Synchronize', 'Trace', 'Telepathy']       0.4        6.6   28
# 280        ['Synchronize', 'Trace', 'Telepathy']       0.8       20.2   38
# ..                                           ...       ...        ...  ...
# 356    ['Chlorophyll', 'Solar Power', 'Harvest']       2.0      100.0   99
# 357                                 ['Levitate']       0.6        1.0   75
# 358      ['Pressure', 'Super Luck', 'Justified']       1.2       47.0   65
# 359                  ['Shadow Tag', 'Telepathy']       0.6       14.0   95
# 360         ['Inner Focus', 'Ice Body', 'Moody']       0.7       16.8   50
# 361         ['Inner Focus', 'Ice Body', 'Moody']       1.5      256.5   80
# 362       ['Thick Fat', 'Ice Body', 'Oblivious']       0.8       39.5   70
# 363       ['Thick Fat', 'Ice Body', 'Oblivious']       1.1       87.6   90
# 364       ['Thick Fat', 'Ice Body', 'Oblivious']       1.4      150.6  110
# 365                   ['Shell Armor', 'Rattled']       0.4       52.5   35
# 366                 ['Swift Swim', 'Water Veil']       1.7       27.0   55
# 367                  ['Swift Swim', 'Hydration']       1.8       22.6   55
# 368        ['Swift Swim', 'Rock Head', 'Sturdy']       1.0       23.4  100
# 369                  ['Swift Swim', 'Hydration']       0.6        8.7   43
# 370                 ['Rock Head', 'Sheer Force']       0.6       42.1   45
# 371                    ['Rock Head', 'Overcoat']       1.1      110.5   65
# 372                      ['Intimidate', 'Moxie']       1.5      102.6   95
# 373                ['Clear Body', 'Light Metal']       0.6       95.2   40
# 374                ['Clear Body', 'Light Metal']       1.2      202.5   60
# 375                ['Clear Body', 'Light Metal']       1.6      550.0   80
# 376                     ['Clear Body', 'Sturdy']       1.7      230.0   80
# 377                   ['Clear Body', 'Ice Body']       1.8      175.0   80
# 378                ['Clear Body', 'Light Metal']       1.9      205.0   80
# 379                                 ['Levitate']       1.4       40.0   80
# 380                                 ['Levitate']       2.0       60.0   80
# 381                                  ['Drizzle']       4.5      352.0  100
# 382                                  ['Drought']       3.5      950.0  100
# 383                                 ['Air Lock']       7.0      206.5  105
# 384                             ['Serene Grace']       0.3        1.1  100
# 385                                 ['Pressure']       1.7       60.8   50
#
#      Speed  sp_Attack  sp_Defense
# 251     70         45          35
# 252     95         65          45
# 253    145        110          75
# 254     45         60          40
# 255     55         85          60
# 256    100        160          80
# 257     40         70          50
# 258     50         85          70
# 259     70        150         110
# 260     35         55          35
# 261     70         90          70
# 262     60         30          41
# 263    100         70          61
# 264     20         45          35
# 265     15         35          55
# 266     65         70          50
# 267     15         35          55
# 268     65         50          70
# 269     30         30          30
# 270     50         50          50
# 271     70         70          70
# 272     30         40          50
# 273     60         70          40
# 274     80        100          60
# 275     85         55          30
# 276    125         85          60
# 277     85         30          30
# 278     65         50         100
# 279     40         25          25
# 280     50         35          35
# ..     ...        ...         ...
# 356     51         68          83
# 357     65         50          80
# 358    115        150          60
# 359     23         23          48
# 360     50         50          50
# 361    100        120          80
# 362     25         40          50
# 363     45         60          70
# 364     65         80          90
# 365     32         64          85
# 366     52        104         105
# 367     52         84         105
# 368     55         90         130
# 369     97         30          55
# 370     50         75          60
# 371     50         95         100
# 372    120        145         130
# 373     30         55          80
# 374     50         75         100
# 375    110        145         150
# 376     50        100         200
# 377     50         50         100
# 378     50         75         150
# 379    110        100         120
# 380    110        130         100
# 381     90        150          90
# 382     90        180         160
# 383    115        180         100
# 384    100        100         100
# 385    180         95          90
#
# [135 rows x 12 columns]

# %%
pokemons[(pokemons.Generation == 3) & (pokemons.Types == 'water')]
# Out:
#      Pokedex Number       Name  Generation  Types        Classfication  \
# 257             258     Mudkip           3  water     Mud Fish Pokémon
# 258             259  Marshtomp           3  water     Mud Fish Pokémon
# 259             260   Swampert           3  water     Mud Fish Pokémon
# 269             270      Lotad           3  water   Water Weed Pokémon
# 270             271     Lombre           3  water        Jolly Pokémon
# 271             272   Ludicolo           3  water     Carefree Pokémon
# 277             278    Wingull           3  water      Seagull Pokémon
# 278             279   Pelipper           3  water   Water Bird Pokémon
# 317             318   Carvanha           3  water       Savage Pokémon
# 318             319   Sharpedo           3  water       Brutal Pokémon
# 319             320    Wailmer           3  water   Ball Whale Pokémon
# 320             321    Wailord           3  water  Float Whale Pokémon
# 338             339   Barboach           3  water     Whiskers Pokémon
# 339             340   Whiscash           3  water     Whiskers Pokémon
# 340             341   Corphish           3  water      Ruffian Pokémon
# 341             342  Crawdaunt           3  water        Rogue Pokémon
# 348             349     Feebas           3  water         Fish Pokémon
# 349             350    Milotic           3  water       Tender Pokémon
# 365             366   Clamperl           3  water      Bivalve Pokémon
# 366             367    Huntail           3  water     Deep Sea Pokémon
# 367             368   Gorebyss           3  water    South Sea Pokémon
# 368             369  Relicanth           3  water    Longevity Pokémon
# 369             370    Luvdisc           3  water   Rendezvous Pokémon
# 381             382     Kyogre           3  water    Sea Basin Pokémon
#
#                                            Abilities  Height_m  Weight_kg  \
# 257                              ['Torrent', 'Damp']       0.4        7.6
# 258                              ['Torrent', 'Damp']       0.7       28.0
# 259                              ['Torrent', 'Damp']       1.5       81.9
# 269         ['Swift Swim', 'Rain Dish', 'Own Tempo']       0.5        2.6
# 270         ['Swift Swim', 'Rain Dish', 'Own Tempo']       1.2       32.5
# 271         ['Swift Swim', 'Rain Dish', 'Own Tempo']       1.5       55.0
# 277           ['Keen Eye', 'Hydration', 'Rain Dish']       0.6        9.5
# 278             ['Keen Eye', 'Drizzle', 'Rain Dish']       1.2       28.0
# 317                    ['Rough Skin', 'Speed Boost']       0.8       20.8
# 318                    ['Rough Skin', 'Speed Boost']       1.8       88.8
# 319          ['Water Veil', 'Oblivious', 'Pressure']       2.0      130.0
# 320          ['Water Veil', 'Oblivious', 'Pressure']      14.5      398.0
# 338       ['Oblivious', 'Anticipation', 'Hydration']       0.4        1.9
# 339       ['Oblivious', 'Anticipation', 'Hydration']       0.9       23.6
# 340  ['Hyper Cutter', 'Shell Armor', 'Adaptability']       0.6       11.5
# 341  ['Hyper Cutter', 'Shell Armor', 'Adaptability']       1.1       32.8
# 348      ['Swift Swim', 'Oblivious', 'Adaptability']       0.6        7.4
# 349    ['Marvel Scale', 'Competitive', 'Cute Charm']       6.2      162.0
# 365                       ['Shell Armor', 'Rattled']       0.4       52.5
# 366                     ['Swift Swim', 'Water Veil']       1.7       27.0
# 367                      ['Swift Swim', 'Hydration']       1.8       22.6
# 368            ['Swift Swim', 'Rock Head', 'Sturdy']       1.0       23.4
# 369                      ['Swift Swim', 'Hydration']       0.6        8.7
# 381                                      ['Drizzle']       4.5      352.0
#
#       Hp  Speed  sp_Attack  sp_Defense
# 257   50     40         70          50
# 258   70     50         85          70
# 259  100     70        150         110
# 269   40     30         30          30
# 270   60     50         50          50
# 271   80     70         70          70
# 277   40     85         30          30
# 278   60     65         50         100
# 317   45     65         90          20
# 318   70    105        140          70
# 319  130     60         70          35
# 320  170     60         90          45
# 338   50     60         48          43
# 339  110     60         78          73
# 340   43     35         80          65
# 341   63     55        120          85
# 348   20     80         15          20
# 349   95     81         60          79
# 365   35     32         64          85
# 366   55     52        104         105
# 367   55     52         84         105
# 368  100     55         90         130
# 369   43     97         30          55
# 381  100     90        150          90

# %%
pokemons[pokemons['Name'] == 'Weedle']
# Out:
#     Pokedex Number    Name  Generation Types  Classfication  \
# 12              13  Weedle           1   bug  Hairy Pokémon
#
#                       Abilities  Height_m  Weight_kg  Hp  Speed  sp_Attack  \
# 12  ['Shield Dust', 'Run Away']       0.3        3.2  40     50         35
#
#     sp_Defense
# 12          30

# %%
po = float(input('Enter Generation: '))
p = input('Enter Type: ').lower()
pokemons[(pokemons.Generation == po) & (pokemons.Types == p)]
# Out:
# Enter Generation: 1
# Enter Type: fire
#      Pokedex Number        Name  Generation Types       Classfication  \
# 3                 4  Charmander           1  fire      Lizard Pokémon
# 4                 5  Charmeleon           1  fire       Flame Pokémon
# 5                 6   Charizard           1  fire       Flame Pokémon
# 36               37      Vulpix           1  fire         Fox Pokémon
# 37               38   Ninetales           1  fire         Fox Pokémon
# 57               58   Growlithe           1  fire       Puppy Pokémon
# 58               59    Arcanine           1  fire   Legendary Pokémon
# 76               77      Ponyta           1  fire  Fire Horse Pokémon
# 77               78    Rapidash           1  fire  Fire Horse Pokémon
# 125             126      Magmar           1  fire    Spitfire Pokémon
# 135             136     Flareon           1  fire       Flame Pokémon
# 145             146     Moltres           1  fire       Flame Pokémon
#
#                                              Abilities  Height_m  Weight_kg  \
# 3                             ['Blaze', 'Solar Power']       0.6        8.5
# 4                             ['Blaze', 'Solar Power']       1.1       19.0
# 5                             ['Blaze', 'Solar Power']       1.7       90.5
# 36   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...       NaN        NaN
# 37   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...       NaN        NaN
# 57           ['Intimidate', 'Flash Fire', 'Justified']       0.7       19.0
# 58           ['Intimidate', 'Flash Fire', 'Justified']       1.9      155.0
# 76            ['Run Away', 'Flash Fire', 'Flame Body']       1.0       30.0
# 77            ['Run Away', 'Flash Fire', 'Flame Body']       1.7       95.0
# 125                     ['Flame Body', 'Vital Spirit']       1.3       44.5
# 135                             ['Flash Fire', 'Guts']       0.9       25.0
# 145                         ['Pressure', 'Flame Body']       2.0       60.0
#
#      Hp  Speed  sp_Attack  sp_Defense
# 3    39     65         52          43
# 4    58     80         64          58
# 5    78    100        104          78
# 36   38     65         41          40
# 37   73    109         67          75
# 57   55     60         70          45
# 58   90     95        110          80
# 76   50     90         85          55
# 77   65    105        100          70
# 125  65     93         95          57
# 135  65     65        130          60
# 145  90     90        100          90

# %%
pok = input("Enter the pokemon's name: ").title()
po = float(input('Enter Generation: '))
p = input('Enter Type: ').lower()

pokemons[(pokemons.Name == pok) & (pokemons.Generation == po) & (pokemons.Types == p)]
# Out:
# Enter the pokemon's name: charmander
# Enter Generation: 1
# Enter Type: FIRE
#    Pokedex Number        Name  Generation Types   Classfication  \
# 3               4  Charmander           1  fire  Lizard Pokémon
#
#                   Abilities  Height_m  Weight_kg  Hp  Speed  sp_Attack  \
# 3  ['Blaze', 'Solar Power']       0.6        8.5  39     65         52
#
#    sp_Defense
# 3          43

# %%
st = input('Please enter how you want to find your Pokemon (Name, Generation, Type): ').title()

if st == 'Name':
    nam = input("Enter the Pokemon's name : ").title()
    print(intro[intro['Name'] == nam])
elif st == 'Generation':
    gen = float(input('Enter Generation: '))
    print('Here is all the Pokemon is this Generation')
    print(intro[intro['Generation'] == gen])
elif st == 'Type':
    typ = input('Enter Type: ').lower()
    print(intro[intro['Types'] == typ])
else:
    print("Pokemon Can't Determine.")
    
pok = input("Enter the pokemon's name: ").title()
pokemons[pokemons['Name'] == pok]
# Out:
# Please enter how you want to find your Pokemon (Name, Generation, Type): charmander
# Pokemon Can't Determine.
# Enter the pokemon's name: n
# Empty DataFrame
# Columns: [Pokedex Number, Name, Generation, Types, Classfication, Abilities, Height_m, Weight_kg, Hp, Speed, sp_Attack, sp_Defense]
# Index: []

# %%
names = pd.Series(mydata['name'])
generation = pd.Series(mydata['generation'])
types = pd.Series(mydata['type1'])
series_dict = { 'Name':  names, 'Generation': generation, 'Types' : types }  # dict of Series, keys are the series names
intro = pd.DataFrame( series_dict )
intro.sample(2)
# Out:
#            Name  Generation  Types
# 796  Celesteela           7  steel
# 267     Cascoon           3    bug

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(str.translate)
# Out:
# Help on method_descriptor:
#
# translate(...)
#     S.translate(table) -> str
#
#     Return a copy of the string S in which each character has been mapped
#     through the given translation table. The table must implement
#     lookup/indexing via __getitem__, for instance a dictionary or list,
#     mapping Unicode ordinals to Unicode ordinals, strings, or None. If
#     this operation raises LookupError, the character is left untouched.
#     Characters mapped to None are deleted.
