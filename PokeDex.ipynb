# %%
 Inputs: 
    Name, Generation, Type
Outputs:
    Name, Generation, Type, Strength, Region, abilities
Algorith: 
    Import pandas
    Get data
    Input Name, Generation, Type
    Sort the database
    Filter out data using the input of the user
    Print out the pokemons attributes

# %%
import pandas as pd

# %%
abilities, pokedex_number, sp_attack, sp_defense,

# %%
mydata = pd.read_csv('pokemon.csv')
mydata.sample(10)
# Out:
#                                          abilities  against_bug  against_dark  \
# 259                            ['Torrent', 'Damp']          1.0           1.0
# 407                ['Mold Breaker', 'Sheer Force']          1.0           1.0
# 722                     ['Overgrow', 'Long Reach']          1.0           1.0
# 733     ['Stakeout', 'Strong Jaw', 'Adaptability']          1.0           1.0
# 43                       ['Chlorophyll', 'Stench']          1.0           1.0
# 246                                  ['Shed Skin']          1.0           1.0
# 533           ['Guts', 'Sheer Force', 'Iron Fist']          0.5           0.5
# 34   ['Cute Charm', 'Magic Guard', 'Friend Guard']          0.5           0.5
# 669                   ['Flower Veil', 'Symbiosis']          0.5           0.5
# 140   ['Swift Swim', 'Battle Armor', 'Weak Armor']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# ...

# %%
names = pd.Series(mydata['name'])
generation = pd.Series(mydata['generation'])
types = pd.Series(mydata['type1'])
series_dict = { 'Name':  names, 'Generation': generation, 'Types' : types }
pokemons = pd.DataFrame( series_dict )
pokemons
# Out:
#            Name  Generation     Types
# 0     Bulbasaur           1     grass
# 1       Ivysaur           1     grass
# 2      Venusaur           1     grass
# 3    Charmander           1      fire
# 4    Charmeleon           1      fire
# 5     Charizard           1      fire
# 6      Squirtle           1     water
# 7     Wartortle           1     water
# 8     Blastoise           1     water
# 9      Caterpie           1       bug
# 10      Metapod           1       bug
# 11   Butterfree           1       bug
# 12       Weedle           1       bug
# 13       Kakuna           1       bug
# 14     Beedrill           1       bug
# 15       Pidgey           1    normal
# 16    Pidgeotto           1    normal
# 17      Pidgeot           1    normal
# 18      Rattata           1    normal
# 19     Raticate           1    normal
# 20      Spearow           1    normal
# 21       Fearow           1    normal
# 22        Ekans           1    poison
# 23        Arbok           1    poison
# ...

# %%
mydata['name'].sample(10)
# Out:
# 480       Mesprit
# 389      Chimchar
# 358         Absol
# 677      Meowstic
# 173     Igglybuff
# 90       Cloyster
# 536    Seismitoad
# 581     Vanillite
# 182        Marill
# 239         Magby
# Name: name, dtype: object

# %%
mydata['type1'].sample(10)
# Out:
# 420      grass
# 22      poison
# 748     ground
# 455      water
# 249       fire
# 7        water
# 163     normal
# 4         fire
# 64     psychic
# 507     normal
# Name: type1, dtype: object

# %%
mydata['type1'].value_counts()
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: type1, dtype: int64

# %%
mydata['generation'].value_counts()
# Out:
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     80
# 6     72
# Name: generation, dtype: int64

# %%
names = pd.Series( data = ['Bulbasaur','Ivysaur','Venusaur','Charmander','Charmeleon'])
generation = pd.Series( data = [1, 2, 3, 4, 5, 6, 7])
types = pd.Series( data = ['ground', 'water', 'electric', 'fire', 'normal', 'bug', 'rock', 'dragon', 'fighting', 'ice', 'poison', 'ghost', 'steel', 'flying', 'dark', 'fairy'])
series_dict = { 'Name':  names, 'Generation': generation, 'Types' : types }
pokemons = pd.DataFrame( series_dict )
pokemons
# Out:
#           Name  Generation     Types
# 0    Bulbasaur         1.0    ground
# 1      Ivysaur         2.0     water
# 2     Venusaur         3.0  electric
# 3   Charmander         4.0      fire
# 4   Charmeleon         5.0    normal
# 5          NaN         6.0       bug
# 6          NaN         7.0      rock
# 7          NaN         NaN    dragon
# 8          NaN         NaN  fighting
# 9          NaN         NaN       ice
# 10         NaN         NaN    poison
# 11         NaN         NaN     ghost
# 12         NaN         NaN     steel
# 13         NaN         NaN    flying
# 14         NaN         NaN      dark
# 15         NaN         NaN     fairy

# %%
pokemons = mydata['name']
generation = mydata['generation']
#types = mydata['type1']
print(pokemons)
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28       Nidoran♀
# 29       Nidorina
#           ...
# 771    Type: Null
# 772      Silvally
# 773        Minior
# 774        Komala
# 775    Turtonator
# 776    Togedemaru
# 777       Mimikyu
# 778       Bruxish
# 779        Drampa
# 780      Dhelmise
# 781      Jangmo-o
# 782      Hakamo-o
# 783       Kommo-o
# 784     Tapu Koko
# 785     Tapu Lele
# 786     Tapu Bulu
# 787     Tapu Fini
# 788        Cosmog
# 789       Cosmoem
# ...

# %%
pokemons = mydata['name']
generation = '1'
types = 'Fire'

pok = input("Enter the pokemon's name or none: ")
if pok in pokemons: 
    print(pok) 
elif pok == generation: 
    print(pok)
elif pok == types: 
    print(pok)
else:
    print("Not able to determone the pokemon")
# Out:
# Enter the pokemon's name or none: 18
# Not able to determone the pokemon

# %%
pv = input("Enter: ").title()
print(pv)
# Out:
# Enter: aabbc
# Aabbc

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help(str.translate)
# Out:
# Help on method_descriptor:
#
# translate(...)
#     S.translate(table) -> str
#
#     Return a copy of the string S in which each character has been mapped
#     through the given translation table. The table must implement
#     lookup/indexing via __getitem__, for instance a dictionary or list,
#     mapping Unicode ordinals to Unicode ordinals, strings, or None. If
#     this operation raises LookupError, the character is left untouched.
#     Characters mapped to None are deleted.
