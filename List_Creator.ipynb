# %%
list_a = []
while True:
    inp = input('input: ')
    if inp == 'quit':
        print(list_a)
        break
    else:
        list_a.append(inp)
# Out:
# input: axew
# input: fraxure
# input: cubchoo
# input: beartic
# input: cryogonal
# input: shelmet
# input: accelgor
# input: stunfisk
# input: mienfoo
# input: mienshao
# input: druddigon
# input: golett
# input: golurk
# input: pawniard
# input: bisharp
# input: bouffalant
# input: rufflet
# input: braviary
# input: vullaby
# input: mandibuzz
# input: heatmor
# input: durant
# input: deino
# input: zweilous
# input: hydreigon
# input: larvesta
# input: volcarona
# input: cobalion
# input: terrakion
# input: virizion
# input: tornadus
# input: thundurus
# input: reshiram
# input: zekrom
# input: landorus
# input: kyurem
# input: keldeo
# input: meloetta
# input: genesect
# input: chespin
# input: quilladin
# input: chesnaught
# input: fennekin
# input: braixen
# input: delphox
# input: froaki
# input: frogadier
# input: greninja
# input: bunnelby
# input: diggersby
# input: fletchling
# input: fletchinder
# input: talonflame
# input: scatterbug
# input: spewpa
# input: vivillon
# ...

# %%
filename = 'All_Pokemon.txt'
with open (filename, 'r') as r:
    for line in r.readlines():
        print(line)
# Out:
# â€˜Bulbasaurâ€™, â€˜Ivysaurâ€™, â€˜Venusaurâ€™, â€˜Charmanderâ€™, â€˜Charmeleonâ€™, â€˜Charizardâ€™, â€˜Squirtleâ€™, â€˜Wartortleâ€™, â€˜Blastoiseâ€™, â€˜Caterpieâ€™, â€˜Metapodâ€™,
#
# â€˜Butterfreeâ€™, â€˜Weedleâ€™, â€˜Kakunaâ€™, â€˜Beedrillâ€™, â€˜Pidgeyâ€™, â€˜Pidgeottoâ€™, â€˜Pidgeotâ€™, â€˜Rattataâ€™, â€˜Raticateâ€™, â€˜Spearowâ€™, â€˜Fearowâ€™, â€˜Ekansâ€™,
#
# â€˜Arbokâ€™, â€˜Pikachuâ€™, â€˜Raichuâ€™, â€˜Sandshrewâ€™, â€˜Sandslashâ€™, â€˜Nidorinaâ€™, â€˜Nidoqueenâ€™, â€˜Nidoranâ€™, â€˜Nidorinoâ€™, â€˜Nidokingâ€™, â€˜Clefairyâ€™, â€˜Clefableâ€™,
#
# â€˜Vulpixâ€™, â€˜Ninetalesâ€™, â€˜Jigglypuffâ€™, â€˜Wigglytuffâ€™, â€˜Zubatâ€™, â€˜Golbatâ€™, â€˜Oddishâ€™, â€˜Gloomâ€™, â€˜Vileplumeâ€™, â€˜Parasâ€™, â€˜Parasectâ€™, â€˜Venonatâ€™,
#
# â€˜Venomothâ€™, â€˜Diglettâ€™, â€˜Dugtrioâ€™, â€˜Meowthâ€™, â€˜Persianâ€™, â€˜Psyduckâ€™, â€˜Golduckâ€™, â€˜Mankeyâ€™, â€˜Primeapeâ€™, â€˜Growlitheâ€™, â€˜Arcanineâ€™, â€˜Poliwagâ€™,
#
# ...
